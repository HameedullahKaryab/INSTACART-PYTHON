# %% [markdown]
# ## Data Wrangling

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# Orders Data
df_ords = pd.read_csv(r'C:\Users\karya\Instacart Basket Analysis\02 Data\Original Data\orders.csv', index_col = False)

# %%
df_ords
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
# Products Data
df_prods = pd.read_csv(r'C:\Users\karya\Instacart Basket Analysis\02 Data\Original Data\products.csv', index_col = False)

# %%
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %% [raw]
# df_ords['user_id'].dtype

# %%
df_ords.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %% [markdown]
# # Changing the Data Type

# %%
# Changing the data type of the variable (user_id) in orders.csv dataframe.

df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
# Dropping eval_set column from orders.csv
df_ords.drop(columns = ['eval_set'])
# Out:
#          order_id user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329       1             1          2                  8
# 1         2398795       1             2          3                  7
# 2          473747       1             3          3                 12
# 3         2254736       1             4          4                  7
# 4          431534       1             5          4                 15
# ...           ...     ...           ...        ...                ...
# 3421078   2266710  206209            10          5                 18
# 3421079   1854736  206209            11          4                 10
# 3421080    626363  206209            12          1                 12
# 3421081   2977660  206209            13          1                 12
# 3421082    272231  206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
# To check whether the data type of the variable has been changed or not.
df_ords['user_id'].dtype
# Out:
# dtype('O')

# %% [markdown]
# # Renaming Columns

# %%
# Renaming the column (order_dow) in orders.csv dataframe.
df_ords.rename(columns = {'order_dow' : 'order of the weak'}, inplace = True)

# %%
# To check whether the code was executed successfully.
df_ords.head()
# Out:
#    order_id user_id eval_set  order_number  order of the weak  \
# 0   2539329       1    prior             1                  2
# 1   2398795       1    prior             2                  3
# 2    473747       1    prior             3                  3
# 3   2254736       1    prior             4                  4
# 4    431534       1    prior             5                  4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
# Renaming the column (order of the weak) in orders.csv dataframe.
df_ords.rename(columns = {'order of the weak' : 'orders_day_of_week'}, inplace = True)

# %%
# To check whether the code was executed successfully.
df_ords.head()
# Out:
#    order_id user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329       1    prior             1                   2
# 1   2398795       1    prior             2                   3
# 2    473747       1    prior             3                   3
# 3   2254736       1    prior             4                   4
# 4    431534       1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
df_ords['order_hour_of_day'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# # Busiest hour for placing order

# %%
# Find highest frequency of order hours 
df['order_hour_of_day'].value_counts()
# 10:00 AM has the highest frequency of orders
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Find highest frequency of order hours
# ----> 2 df['order_hour_of_day'].value_counts()
#
# NameError: name 'df' is not defined

# %%
#To find the highest frquency of the order hour
df_ords['order_hour_of_day'].value_counts()
# The output bellow shows that the busiest hour for placing order is 10:00 AM with the frequency of 288418
# Out:
# order_hour_of_day
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: count, dtype: int64

# %% [markdown]
# # Importing the Department data set

# %%
# Importing the Department data set
df_dep = pd.read_csv(r'C:\Users\karya\Instacart Basket Analysis\02 Data\Original Data\departments.csv', index_col = False)

# %%
df_dep.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_dep.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %% [markdown]
# # Transposing the dataframe

# %%
# Transposing the dataframe
df_dep_t = df_dep.T

# %%
# Adding an index to the dataframe
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# Take the first row of df_dep_t for the header.
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
#  Copy everything from the first row onward from the df_dep_t dataframe into a new dataframe.
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
# use the list of column names in new_header variable as new header
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# # Data Dictionery

# %%
# Determine the meaning behind a value of 4 in the "department_id" column within the df_prods dataframe using a data dictionary. so we should refer to the departments.csv data set where we can see the same "departmet_id" column 
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %% [markdown]
# # Subsetting

# %%
# Creating a subset of breakfast from the df_prods dataframe
df_breakfast = df_prods[df_prods['department_id'] ==14]

# %%
df_breakfast
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %%
# method 2
df_breakfst_2 = df_prods.loc[df_prods['department_id'] == 14]

# %%
# Method 3
df_breakfast_3 = df_prods.loc[df_prods['department_id'].isin([14])]

# %%
# Subset of all observations from the entire dataframe that include items from the: alcohol, deli, beverages, and meat/seafood departments.
df_dinner_parties = df_prods.loc[df_prods['department_id'].isin([5,7,12,20])]

# %%
df_dinner_parties
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %% [markdown]
# ##  Q8. The last dataframe has (7650) Rows and 5 columns.

# %%
# Information about the customer with a "user_id" of “1.” 
df_customer_userid_1 = df_ords.loc[df_ords['user_id'] == 1]

# %%
df_customer_userid_1
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, eval_set, order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order]
# Index: []

# %%
# Q10. Details about this user’s behavior
df_customer_userid_1.describe()
# Out:
#        order_id  order_number  orders_day_of_week  order_hour_of_day  \
# count       0.0           0.0                 0.0                0.0
# mean        NaN           NaN                 NaN                NaN
# std         NaN           NaN                 NaN                NaN
# min         NaN           NaN                 NaN                NaN
# 25%         NaN           NaN                 NaN                NaN
# 50%         NaN           NaN                 NaN                NaN
# 75%         NaN           NaN                 NaN                NaN
# max         NaN           NaN                 NaN                NaN
#
#        days_since_prior_order
# count                     0.0
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN

# %% [markdown]
# # Exporting Dataframes

# %%
path = r'C:\Users\karya\Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\karya\\Instacart Basket Analysis'

# %% [markdown]
# # Exporting df_ords

# %%
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))

# %% [markdown]
# # Exporting df_dep_t_new

# %%
df_dep_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'deparments_wrangled.csv'))
